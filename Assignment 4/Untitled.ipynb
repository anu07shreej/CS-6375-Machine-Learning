# %%
import numpy as np
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.neighbors import KNeighborsClassifier

# %%
cancer_trn=np.loadtxt(open('C:/Users/anu07/Desktop/Fall19/wdbc_trn.csv', "rb"), delimiter=",")
Xtrn=cancer_trn[:,1:]
ytrn=cancer_trn[:,0]

cancer_tst=np.loadtxt(open('C:/Users/anu07/Desktop/Fall19/wdbc_tst.csv', "rb"), delimiter=",")
Xtst=cancer_tst[:,1:]
ytst=cancer_tst[:,0]

cancer_val=np.loadtxt(open("C:/Users/anu07/Desktop/Fall19/wdbc_val.csv", "rb"), delimiter=",")
Xval=cancer_val[:,1:]
yval=cancer_val[:,0]

# %%
neigh = KNeighborsClassifier(n_neighbors=5,algorithm='kd_tree')
neigh.fit(Xtrn,ytrn) 
ytst_pred=neigh.predict(Xtst)
print(accuracy_score(ytst,ytst_pred)*100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-ae25e8fd754a> in <module>
#       2 neigh.fit(Xtrn,ytrn)
#       3 ytst_pred=neigh.predict(Xtst)
# ----> 4 print(accuracy_score(ytst,ytst_pred)*100)
#
# NameError: name 'accuracy_score' is not defined
